# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel(r"C:\Users\wasia\Desktop\Data Science\Data science Property Price Prediction Project\Step 6 Outlier and removal\gurgaon_properties_outlier_treated_v2.xlsx")

# %%
df.shape
# Out:
# (3553, 24)

# %%
df.head()
# Out:
#   property_type                                   society      sector  price  \
# 0         house                               independent    sector 4   0.67
# 1          flat                               zara aavaas  sector 104   0.65
# 2         house               DLF New Town Heights 24.0 ?   sector 86   2.47
# 3          flat                   shree vardhman victoria   sector 70   1.65
# 4          flat  central park resort belgravia residences   sector 48   6.25
#
#    price_per_sqft  area                                       areaWithType  \
# 0            8557   783                          Plot area 87(72.74 sq.m.)
# 1            8519   763                     Carpet area: 763 (70.89 sq.m.)
# 2            7719  3200  Plot area 3200(297.29 sq.m.)Built Up area: 280...
# 3            8462  1950  Super Built up area 1950(181.16 sq.m.)Carpet a...
# 4           24300  2572                   Carpet area: 2880 (267.56 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 0        3         2       1         1       South  Moderately Old
# 1        3         2       2         7         NaN    New Property
# 2        4         4      3+         0        West  Moderately Old
# 3        3         4       3         5  South-East  Relatively New
# 4        3         5      3+         5  South-East  Moderately Old
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN          783.0          NaN           0             0
# 1                  NaN            NaN        763.0           0             0
# 2                  NaN         2800.0       2200.0           0             1
# 3               1950.0            NaN       1161.0           0             1
# 4                  NaN            NaN       2880.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score  \
# 0           0           1       1                0            19
# 1           0           0       0                0            65
# 2           0           1       0                2           130
# 3           0           0       1                2            49
# 4           0           0       0                2            49
#
#    area_room_ratio
# 0       261.000000
# 1       254.333333
# 2       800.000000
# 3       650.000000
# 4       857.333333

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   0
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                  0
# facing                 1008
# agePossession             0
# super_built_up_area    1677
# built_up_area          1969
# carpet_area            1712
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %% [markdown]
# ### Built up area

# %%
sns.scatterplot(x='built_up_area', y='super_built_up_area', data=df)
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
sns.scatterplot(x='built_up_area', y='carpet_area', data=df)
# Out:
# <Axes: xlabel='built_up_area', ylabel='carpet_area'>

# %%
((df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())).sum()
# Out:
# np.int64(0)

# %%
all_present_df = df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))]

# %%
all_present_df.shape
# Out:
# (531, 24)

# %%
# Calculate the median ratio of super built-up area to built-up area
super_to_built_up_ratio = (all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()
super_to_built_up_ratio
# Out:
# np.float64(1.105263157894737)

# %%
# calculate the median ratio of carpet area to built-up area
carpet_to_built_up_ratio = (all_present_df['carpet_area']/all_present_df['built_up_area']).median()
carpet_to_built_up_ratio
# Out:
# np.float64(0.9)

# %%
# filter rows where super built-up area is missing, built-up area is present, and carpet area is present
sbc_df = df[
    df['super_built_up_area'].notna() &
    df['built_up_area'].isna() &
    df['carpet_area'].notna()
]

# %%
sbc_df.head()
# Out:
#    property_type                               society      sector  price  \
# 3           flat               shree vardhman victoria   sector 70   1.65
# 16          flat               indiabulls centrum park  sector 103   2.14
# 25          flat  shapoorji pallonji joyville gurugram  sector 102   1.75
# 42          flat                         sbtl caladium  sector 109   1.80
# 73          flat                       eldeco accolade  sohna road   1.30
#
#     price_per_sqft  area                                       areaWithType  \
# 3             8462  1950  Super Built up area 1950(181.16 sq.m.)Carpet a...
# 16            7443  2875  Super Built up area 2875(267.1 sq.m.)Carpet ar...
# 25           15514  1128  Super Built up area 1852(172.06 sq.m.)Carpet a...
# 42            7073  2545  Super Built up area 2545(236.44 sq.m.)Carpet a...
# 73            7424  1751  Super Built up area 1751(162.67 sq.m.)Carpet a...
#
#     bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 3         3         4       3         5  South-East  Relatively New
# 16        4         6      3+         7        East  Relatively New
# 25        3         3      3+         1        East  Relatively New
# 42        3         3      3+        10        East  Relatively New
# 73        3         3      3+        10        East  Relatively New
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 3                1950.0            NaN       1161.0           0             1
# 16               2875.0            NaN       2550.0           0             1
# 25               1852.0            NaN       1128.0           0             0
# 42               2545.0            NaN       1527.0           0             0
# 73               1751.0            NaN       1290.0           0             0
#
#     store room  pooja room  others  furnishing_type  luxury_score  \
# 3            0           0       1                2            49
# 16           0           0       0                0           142
# 25           0           0       0                0            49
# 42           0           0       0                0           174
# 73           0           0       0                0            49
#
#     area_room_ratio
# 3        650.000000
# 16       718.750000
# 25       376.000000
# 42       848.333333
# 73       583.666667

# %%
# Impute built-up area using the average of the calculated values
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# Out:
# C:\Users\wasia\AppData\Local\Temp\ipykernel_3432\2522366982.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# C:\Users\wasia\AppData\Local\Temp\ipykernel_3432\2522366982.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)

# %%
df.update(sbc_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   0
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                  0
# facing                 1008
# agePossession             0
# super_built_up_area    1677
# built_up_area          1547
# carpet_area            1712
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# filter rows where super built-up area is missing, built-up area is present, and carpet area is missing
sb_df = df[
    df['super_built_up_area'].notna() &
    df['built_up_area'].isna() &
    df['carpet_area'].isna()
]

# %%
sb_df.head()
# Out:
#    property_type                           society      sector  price  \
# 21          flat                   eldeco accolade  sohna road   0.78
# 39          flat                        bptp terra  sector 37d   1.55
# 40          flat  emaar mgf emerald floors premier   sector 65   3.00
# 41          flat                    m3m the marina   sector 68   2.22
# 45          flat               experion windchants  sector 112   3.75
#
#     price_per_sqft  area                            areaWithType  bedRoom  \
# 21            6171  1264  Super Built up area 1264(117.43 sq.m.)        2
# 39            8559  1811  Super Built up area 1811(168.25 sq.m.)        3
# 40           15190  1975  Super Built up area 1975(183.48 sq.m.)        4
# 41           14323  1550     Super Built up area 1550(144 sq.m.)        3
# 45           13383  2802  Super Built up area 2802(260.31 sq.m.)        3
#
#     bathroom balcony  floorNum      facing   agePossession  \
# 21         2       2         3         NaN  Relatively New
# 39         3      3+        11       South  Relatively New
# 40         4      3+         2  South-East  Relatively New
# 41         2       3         4        East  Relatively New
# 45         5      3+        22  South-West  Relatively New
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 21               1264.0            NaN          NaN           0             0
# 39               1811.0            NaN          NaN           0             0
# 40               1975.0            NaN          NaN           0             1
# 41               1550.0            NaN          NaN           0             0
# 45               2802.0            NaN          NaN           0             1
#
#     store room  pooja room  others  furnishing_type  luxury_score  \
# 21           0           0       0                0            72
# 39           0           0       0                0            79
# 40           0           0       0                0            87
# 41           0           0       0                0            44
# 45           0           0       0                2            49
#
#     area_room_ratio
# 21       632.000000
# 39       603.666667
# 40       493.750000
# 41       516.666667
# 45       934.000000

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# Out:
# C:\Users\wasia\AppData\Local\Temp\ipykernel_3432\1714170073.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# C:\Users\wasia\AppData\Local\Temp\ipykernel_3432\1714170073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)

# %%
df.update(sb_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   0
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                  0
# facing                 1008
# agePossession             0
# super_built_up_area    1677
# built_up_area           672
# carpet_area            1712
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# filter rows where super built-up area is missing, built-up area is missing, and carpet area is present
c_df = df[
    df['super_built_up_area'].isna() &
    df['built_up_area'].isna() &
    df['carpet_area'].notna()
]

# %%
c_df.head()
# Out:
#   property_type                                   society      sector  price  \
# 1          flat                               zara aavaas  sector 104   0.65
# 4          flat  central park resort belgravia residences   sector 48   6.25
# 5          flat                             gls avenue 51   sector 92   0.50
# 7          flat                   signature global synera   sector 81   0.38
# 8          flat                           the close south   sector 50   3.25
#
#    price_per_sqft  area                      areaWithType  bedRoom  bathroom  \
# 1            8519   763    Carpet area: 763 (70.89 sq.m.)        3         2
# 4           24300  2572  Carpet area: 2880 (267.56 sq.m.)        3         5
# 5            7812   640    Carpet area: 640 (59.46 sq.m.)        3         3
# 7            9500   400    Carpet area: 400 (37.16 sq.m.)        1         1
# 8           12810  2537   Carpet area: 2537 (235.7 sq.m.)        3         4
#
#   balcony  floorNum      facing   agePossession  super_built_up_area  \
# 1       2         7         NaN    New Property                  NaN
# 4      3+         5  South-East  Moderately Old                  NaN
# 5       1        12         NaN    New Property                  NaN
# 7       2         3  South-West  Relatively New                  NaN
# 8      3+         4  South-East    Old Property                  NaN
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 1            NaN        763.0           0             0           0
# 4            NaN       2880.0           0             1           0
# 5            NaN        640.0           0             0           0
# 7            NaN        400.0           0             0           0
# 8            NaN       2537.0           0             1           0
#
#    pooja room  others  furnishing_type  luxury_score  area_room_ratio
# 1           0       0                0            65       254.333333
# 4           0       0                2            49       857.333333
# 5           0       0                1            95       213.333333
# 7           0       0                0            43       400.000000
# 8           0       0                2           135       845.666667

# %%
# Impute built-up area using the calculated value based on carpet area
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# Out:
# C:\Users\wasia\AppData\Local\Temp\ipykernel_3432\1311460402.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# C:\Users\wasia\AppData\Local\Temp\ipykernel_3432\1311460402.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)

# %%
df.update(c_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   0
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                  0
# facing                 1008
# agePossession             0
# super_built_up_area    1677
# built_up_area             0
# carpet_area            1712
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(x = 'built_up_area',y = 'price', data = df)
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
# As we acan see in the scattered plot there are some anomalies in the data where area  is less than 2000 and price is greater than 2.5 crores. 
anamoly_df = df[(df['built_up_area'] < 2000) & (df['price'] > 2.5)][['price','area','built_up_area']]
anamoly_df.sample(5)
# Out:
#       price  area  built_up_area
# 1180   2.80  1650         1493.0
# 565    3.15  1548         1548.0
# 1305   2.55  2273         1773.0
# 675    3.30  1665         1665.0
# 2988   4.31  1350         1350.0

# %%
# putting built_up_area equals to area in anamoly_df
anamoly_df['built_up_area'] = anamoly_df['area']

# %%
df.update(anamoly_df)

# %%
sns.scatterplot(x = df['built_up_area'],y = df['price'], data=df)
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)

# %%
df.head()
# Out:
#   property_type                                   society      sector  price  \
# 0         house                               independent    sector 4   0.67
# 1          flat                               zara aavaas  sector 104   0.65
# 2         house               DLF New Town Heights 24.0 ?   sector 86   2.47
# 3          flat                   shree vardhman victoria   sector 70   1.65
# 4          flat  central park resort belgravia residences   sector 48   6.25
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum      facing  \
# 0            8557        3         2       1         1       South
# 1            8519        3         2       2         7         NaN
# 2            7719        4         4      3+         0        West
# 3            8462        3         4       3         5  South-East
# 4           24300        3         5      3+         5  South-East
#
#     agePossession  built_up_area  study room  servant room  store room  \
# 0  Moderately Old          783.0           0             0           0
# 1    New Property          848.0           0             0           0
# 2  Moderately Old         2800.0           0             1           0
# 3  Relatively New         1527.0           0             1           0
# 4  Moderately Old         3200.0           0             1           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           1       1                0            19
# 1           0       0                0            65
# 2           1       0                2           130
# 3           0       1                2            49
# 4           0       0                2            49

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               0
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum              0
# facing             1008
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %% [markdown]
# ### facing

# %%
df['facing'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# drop column facing as it is difficult to impute and has many unique values
df.drop(columns=['facing'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                               society      sector  price  \
# 565          house                           independent   sector 57   3.15
# 2918          flat  shapoorji pallonji joyville gurugram  sector 102   1.20
# 2568          flat                            rof ananda   sector 95   0.25
# 2878          flat                    ansals duplex flat    sector 2   0.95
# 2796         house                           independent    sector 2   6.00
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 565            20349        5         4      3+         2  Moderately Old
# 2918           14563        2         2       3         0  Relatively New
# 2568            6579        1         1       1         4    New Property
# 2878            7308        2         3       2         1    Old Property
# 2796           20000        4         4       1         2  Relatively New
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 565          1548.0           0             0           1           0       0
# 2918         1073.0           0             0           0           0       0
# 2568          344.0           0             0           0           0       0
# 2878         1444.0           1             0           0           0       0
# 2796         3000.0           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 565                 2            60
# 2918                0            49
# 2568                0             0
# 2878                2            20
# 2796                0             0

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %% [markdown]
# ### agePossession

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1605
# New Property           669
# Moderately Old         544
# Old Property           293
# Undefined              291
# Under Construction     151
# Name: count, dtype: int64

# %%
df[df['agePossession'] == 'Undefined']
# Out:
#      property_type                    society      sector  price  \
# 11            flat                  dnha cghs    sector 1   0.85
# 23            flat               milan cghs 9   sector 39   2.00
# 29            flat               tulip violet   sector 69   1.20
# 44           house                independent    sector 8   0.45
# 46            flat        trisara our homes 3  sohna road   0.40
# ...            ...                        ...         ...    ...
# 3516         house                independent  sector 103   2.25
# 3533         house                independent    sector 3   0.92
# 3541         house  Shivaji Nagar Residential   sector 11   3.08
# 3544         house                independent    sector 9   0.22
# 3551         house                independent   sector 50  13.20
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum agePossession  \
# 11              3864        3         3       0         5     Undefined
# 23              8333        3         3      3+         0     Undefined
# 29             10909        2         3       0         0     Undefined
# 44              9000        1         1       1         3     Undefined
# 46              4479        2         2       2         1     Undefined
# ...              ...      ...       ...     ...       ...           ...
# 3516            6367        3         5      3+        10     Undefined
# 3533           15257        4         1       0         1     Undefined
# 3541           11407        6         4       2         1     Undefined
# 3544            7407        2         2       2         1     Undefined
# 3551           27155        6         6       0         2     Undefined
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 11           2200.0           0             0           0           0       0
# 23           2400.0           0             0           0           0       0
# 29           1100.0           0             0           0           0       0
# 44            556.0           0             0           0           0       0
# 46            900.0           0             0           0           0       0
# ...             ...         ...           ...         ...         ...     ...
# 3516         3534.0           0             0           0           0       0
# 3533          603.0           0             0           0           0       0
# 3541         2700.0           0             0           0           0       0
# 3544           37.0           0             0           0           0       0
# 3551         4861.0           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 11                  0             0
# 23                  0             0
# 29                  0            54
# 44                  0             0
# 46                  0             0
# ...               ...           ...
# 3516                0             0
# 3533                0             0
# 3541                0             0
# 3544                0             0
# 3551                0             0
#
# [291 rows x 18 columns]

# %%
# Impute 'Undefined' values in 'agePossession' based on the mode of the sector and property type
def mode_based_imputation(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector']) & (df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1715
# New Property           724
# Moderately Old         582
# Old Property           326
# Under Construction     154
# Undefined               52
# Name: count, dtype: int64

# %%
# Impute 'Undefined' values in 'agePossession' based on the mode of the sector
def mode_based_imputation2(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation2,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1724
# New Property           724
# Moderately Old         589
# Old Property           329
# Under Construction     154
# Undefined               33
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation3,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1726
# New Property           724
# Moderately Old         620
# Old Property           329
# Under Construction     154
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.to_csv('gurgaon_properties_missing_value_imputation.csv',index=False)

# %%
df.shape
# Out:
# (3553, 18)

# %%
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv
import pymysql
import pyodbc

# Load .env variables
from dotenv import load_dotenv
print(load_dotenv())

# Create MySQL connection (AWS RDS)
mysql_engine = create_engine(
    f"mysql+pymysql://{os.getenv('MYSQL_USER')}:{os.getenv('MYSQL_PASS')}@{os.getenv('MYSQL_HOST')}/{os.getenv('MYSQL_DB')}"
)

# Create MSSQL connection
mssql_engine = create_engine(
    f"mssql+pyodbc://{os.getenv('MSSQL_USER')}:{os.getenv('MSSQL_PASS')}@{os.getenv('MSSQL_HOST')}/{os.getenv('MSSQL_DB')}?driver={os.getenv('MSSQL_DRIVER')}&Encrypt=yes&TrustServerCertificate=no"
)
# Out:
# True

# %%
df.to_sql("gurgaon_properties_missing_value_imputation", con=mysql_engine, if_exists='replace', index=False)
# Out:
# 3553

# %%
df.to_sql("gurgaon_properties_missing_value_imputation", con=mssql_engine, if_exists='replace', index=False)
# Out:
# 73

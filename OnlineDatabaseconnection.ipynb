# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from -r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: sqlalchemy in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from -r requirements.txt (line 2)) (2.0.41)
# Requirement already satisfied: pymysql in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from -r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: pyodbc in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from -r requirements.txt (line 4)) (5.2.0)
# Requirement already satisfied: python-dotenv in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from -r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: openpyxl in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from -r requirements.txt (line 6)) (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: greenlet>=1 in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from sqlalchemy->-r requirements.txt (line 2)) (3.2.3)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy->-r requirements.txt (line 2))
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: et-xmlfile in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from openpyxl->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\wasi\desktop\capstone-project-property-price-prediction-model\env\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Installing collected packages: typing-extensions
# Successfully installed typing-extensions-4.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import pymysql
import pyodbc

# %%
# Load .env variables
from dotenv import load_dotenv
print(load_dotenv())
# Out:
# True

# %%
# Create MySQL connection (AWS RDS)
mysql_engine = create_engine(
    f"mysql+pymysql://{os.getenv('MYSQL_USER')}:{os.getenv('MYSQL_PASS')}@{os.getenv('MYSQL_HOST')}/{os.getenv('MYSQL_DB')}"
)

# Create MSSQL connection
mssql_engine = create_engine(
    f"mssql+pyodbc://{os.getenv('MSSQL_USER')}:{os.getenv('MSSQL_PASS')}@{os.getenv('MSSQL_HOST')}/{os.getenv('MSSQL_DB')}?driver={os.getenv('MSSQL_DRIVER')}&Encrypt=yes&TrustServerCertificate=no"
)

# %%
# # Step 1: Read from AWS MySQL
df = pd.read_sql("SELECT * FROM salaries", con=mysql_engine, index_col="index")
df.head()
# Out:
#        work_year experience_level employment_type                  job_title  \
# index
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT  Machine Learning Engineer
# 2           2024               SE              FT  Machine Learning Engineer
# 3           2024               SE              FT  Machine Learning Engineer
# 4           2024               SE              FT  Machine Learning Engineer
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# index
# 0       90000             USD          90000                 AE             0
# 1      180500             USD         180500                 US             0
# 2       96200             USD          96200                 US             0
# 3      235000             USD         235000                 AU             0
# 4      175000             USD         175000                 AU             0
#
#       company_location company_size
# index
# 0                   AE            L
# 1                   US            M
# 2                   US            M
# 3                   AU            M
# 4                   AU            M

# %%
# # Step 2: Read from SQL Server (MSSQL) with azure as a database
df2 = pd.read_sql("SELECT * FROM salaries", con=mssql_engine)
df2.head()
# Out:
#    index  work_year experience_level employment_type  \
# 0      0       2024               SE              FT
# 1      1       2024               SE              FT
# 2      2       2024               SE              FT
# 3      3       2024               SE              FT
# 4      4       2024               SE              FT
#
#                    job_title  salary salary_currency  salary_in_usd  \
# 0                AI Engineer   90000             USD          90000
# 1  Machine Learning Engineer  180500             USD         180500
# 2  Machine Learning Engineer   96200             USD          96200
# 3  Machine Learning Engineer  235000             USD         235000
# 4  Machine Learning Engineer  175000             USD         175000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 AE             0               AE            L
# 1                 US             0               US            M
# 2                 US             0               US            M
# 3                 AU             0               AU            M
# 4                 AU             0               AU            M
